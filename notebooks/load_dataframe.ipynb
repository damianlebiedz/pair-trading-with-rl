# %%
from modules.data_services.data_utils import load_dataframe

# %load_ext autoreload
# %autoreload 2

# %%
file_name = "..."
directory = "..."

df = load_dataframe(file_name, directory)

# %%
df
# Out:
#                   pair          ssd  corr_log_returns  eg_p_value
# 0      XRPUSDT-DOTUSDT    31.270303          0.717499    0.001216
# 1     DOGEUSDT-BCHUSDT   111.537232          0.555930    0.005617
# 2     DOGEUSDT-LTCUSDT  1068.650222          0.639888    0.018614
# 3    DOGEUSDT-SHIBUSDT  1520.056417          0.803805    0.018709
# 4     SHIBUSDT-LTCUSDT  4905.988992          0.582342    0.056829
# ..                 ...          ...               ...         ...
# 100   TRXUSDT-SHIBUSDT  5459.690222          0.363579    0.868339
# 101   SOLUSDT-AVAXUSDT   916.143713          0.797746    0.868473
# 102    BTCUSDT-ADAUSDT  1510.401801          0.729603    0.885145
# 103    SOLUSDT-ADAUSDT  1481.097795          0.744720    0.894377
# 104    ETHUSDT-ADAUSDT  1306.600143          0.767272    0.897078
#
# [105 rows x 4 columns]
