# %%
from modules.data_services.data_utils import load_strategy_result

# %load_ext autoreload
# %autoreload 2

# %%
file_name = "test_multi_pair_2024-07-01_2024-09-01"
directory = "multi_pair_static-static"

result = load_strategy_result(file_name, directory)

# %%
result.stats

# %%
result.data
